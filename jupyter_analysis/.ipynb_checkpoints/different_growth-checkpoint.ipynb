# %%
import glob
import torch
import numpy as np
from collections import defaultdict
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


def compute_flops(grow, before_grow = 1.400e+09, after_grow = 5.590e+09, n_students=1):  ## after = 4x before 
    """
        before_grow: 1395898880 for tf, 1.400e+09 for "ours." and "ours. ens."
        
    """
    epochs = 100

    our_flops_by_epochs = np.array([before_grow * n_students] * grow + [after_grow] * (epochs - grow))
    our_flops = our_flops_by_epochs.cumsum()
    return our_flops
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 6
#       4 from collections import defaultdict
#       5 import pandas as pd
# ----> 6 import seaborn as sns
#       7 import matplotlib.pyplot as plt
#      10 def compute_flops(grow, before_grow = 1.400e+09, after_grow = 5.590e+09, n_students=1):  ## after = 4x before
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# !conda install seaborn
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.14.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr3/graduate/piotrt/.conda/envs/anytime
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1s             |       h166bdaf_0         2.1 MB  conda-forge
#     pandas-1.5.1               |   py38h8f669ce_1        13.2 MB  conda-forge
#     patsy-0.5.3                |     pyhd8ed1ab_0         189 KB  conda-forge
#     pytz-2022.6                |     pyhd8ed1ab_0         235 KB  conda-forge
#     scipy-1.9.3                |   py38h8ce737c_1        26.3 MB  conda-forge
#     seaborn-0.11.2             |       hd8ed1ab_0           4 KB  conda-forge
#     seaborn-base-0.11.2        |     pyhd8ed1ab_0         223 KB  conda-forge
#     statsmodels-0.13.5         |   py38h26c90d9_2        11.2 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        53.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas             conda-forge/linux-64::pandas-1.5.1-py38h8f669ce_1
#   patsy              conda-forge/noarch::patsy-0.5.3-pyhd8ed1ab_0
#   pytz               conda-forge/noarch::pytz-2022.6-pyhd8ed1ab_0
#   scipy              conda-forge/linux-64::scipy-1.9.3-py38h8ce737c_1
#   seaborn            conda-forge/noarch::seaborn-0.11.2-hd8ed1ab_0
#   seaborn-base       conda-forge/noarch::seaborn-base-0.11.2-pyhd8ed1ab_0
#   statsmodels        conda-forge/linux-64::statsmodels-0.13.5-py38h26c90d9_2
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1q-h166bdaf_1 --> 1.1.1s-h166bdaf_0
#
#
# Proceed ([y]/n)?

# %%
path = "/projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_*"
replace_name = "cifar100_ours_ens_bank_size_8_v2_grow_"
all_paths = glob.glob(path)
# all_paths

# %%
store = defaultdict(list)
for path in all_paths:
    try:
        checkpoint = torch.load(path + "/checkpoint.pth.tar")
        grow_epoch = int(path.split("/")[-1].replace(replace_name, "").split("_")[0])
        acc = checkpoint['recorder'].epoch_accuracy[:,1][-1]
        store[grow_epoch].append(acc)
    except Exception as e:
        print("Skipped failed run.")
        print("Exception:", e)
        
for k in store:
    store[k] = np.array(store[k])
# Out:
# Exception: [Errno 2] No such file or directory: '/projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_68_seed_92551/checkpoint.pth.tar'
# skipped falied run. path= /projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_68_seed_92551
#
# Exception: [Errno 2] No such file or directory: '/projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_42_seed_96790/checkpoint.pth.tar'
# skipped falied run. path= /projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_42_seed_96790
#
# Exception: [Errno 2] No such file or directory: '/projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_28_seed_56374/checkpoint.pth.tar'
# skipped falied run. path= /projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_28_seed_56374
#
# Exception: [Errno 2] No such file or directory: '/projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_27_seed_71697/checkpoint.pth.tar'
# skipped falied run. path= /projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_27_seed_71697
#
# Exception: [Errno 2] No such file or directory: '/projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_42_seed_7123/checkpoint.pth.tar'
# skipped falied run. path= /projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_42_seed_7123
#
# Exception: [Errno 2] No such file or directory: '/projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_78_seed_92551/checkpoint.pth.tar'
# skipped falied run. path= /projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_78_seed_92551
#
# Exception: [Errno 2] No such file or directory: '/projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_73_seed_92551/checkpoint.pth.tar'
# skipped falied run. path= /projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_73_seed_92551
#
# Exception: [Errno 2] No such file or directory: '/projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_42_seed_93100/checkpoint.pth.tar'
# skipped falied run. path= /projectnb/ivc-ml/chaupham/anytime/param_share/incremental_training/snapshots/cifar100_ours_ens_bank_size_8_v2_grow_42_seed_93100

# %%
store ## key: grow_epoch, value: accuracy for each run
# Out:
# defaultdict(list,
#             {74: array([79.14, 78.73, 79.11], dtype=float32),
#              43: array([79.35, 78.77, 78.84], dtype=float32),
#              57: array([79.39, 78.59, 79.12], dtype=float32),
#              49: array([79.24, 78.97, 79.2 ], dtype=float32),
#              68: array([79.3], dtype=float32),
#              48: array([78.79, 79.33, 78.85], dtype=float32),
#              80: array([77.31, 78.86], dtype=float32),
#              38: array([78.9 , 79.49, 79.41], dtype=float32),
#              33: array([78.85, 79.12, 78.77], dtype=float32),
#              18: array([79.21, 79.42, 79.36, 79.42], dtype=float32),
#              94: array([78.59, 78.35, 77.92, 77.45, 77.1 , 77.51, 78.27], dtype=float32),
#              42: array([78.82, 79.37, 79.12, 79.59], dtype=float32),
#              53: array([79.26], dtype=float32),
#              28: array([79.52, 79.47, 79.35], dtype=float32),
#              95: array([77.44, 77.39], dtype=float32),
#              96: array([77.51, 76.32], dtype=float32),
#              27: array([79.1 , 79.46, 79.22], dtype=float32),
#              63: array([79.19, 79.34, 79.11], dtype=float32),
#              83: array([79.13, 77.34, 77.75], dtype=float32),
#              93: array([77.56], dtype=float32),
#              78: array([78.87], dtype=float32),
#              73: array([79.33], dtype=float32),
#              88: array([77.96], dtype=float32),
#              23: array([79.5 , 79.32], dtype=float32),
#              13: array([79.76], dtype=float32),
#              58: array([79.33], dtype=float32),
#              98: array([74.62], dtype=float32),
#              5: array([79.27], dtype=float32)})

# %%
data_ours_ens = sorted([(k, np.mean(v), compute_flops(grow=k, n_students=1)[-1]) for k, v in store.items()])
data_ours_ens  ## (growth_epoch, mean_accuracy, flops)
# Out:
# [(5, 79.27, 538050000000.0),
#  (13, 79.76, 504530000000.0),
#  (18, 79.3525, 483580000000.0),
#  (23, 79.41, 462630000000.0),
#  (27, 79.26, 445870000000.0),
#  (28, 79.44666, 441680000000.0),
#  (33, 78.91333, 420730000000.0),
#  (38, 79.26667, 399780000000.0),
#  (42, 79.225, 383020000000.0),
#  (43, 78.986664, 378830000000.0),
#  (48, 78.99, 357880000000.0),
#  (49, 79.136665, 353690000000.0),
#  (53, 79.26, 336930000000.0),
#  (57, 79.03333, 320170000000.0),
#  (58, 79.33, 315980000000.0),
#  (63, 79.21333, 295030000000.0),
#  (68, 79.3, 274080000000.0),
#  (73, 79.33, 253130000000.0),
#  (74, 78.99333, 248940000000.0),
#  (78, 78.87, 232180000000.0),
#  (80, 78.085, 223800000000.0),
#  (83, 78.07333, 211230000000.0),
#  (88, 77.96, 190280000000.0),
#  (93, 77.56, 169330000000.0),
#  (94, 77.884285, 165140000000.0),
#  (95, 77.415, 160950000000.0),
#  (96, 76.915, 156760000000.0),
#  (98, 74.62, 148380000000.0)]

# %%
target = (0, 79.45, 5.464e11)

data = [target] + data_ours_ens  ## add Target to the results

## convert to dataframe for generating graph
grow_epoch, acc, flops = zip(*data)
df = pd.DataFrame(data={"grow_epoch": grow_epoch, "acc": acc, "FLOPS": np.array(flops)/target[-1]})
df["color"] = "MixGrowth Ens"
df.iloc[0, -1] = "Target Network"
df
# Out:
#     grow_epoch        acc     FLOPS           color
# 0            0  79.450000  1.000000  Target Network
# 1            5  79.269997  0.984718   MixGrowth Ens
# 2           13  79.760002  0.923371   MixGrowth Ens
# 3           18  79.352501  0.885029   MixGrowth Ens
# 4           23  79.410004  0.846687   MixGrowth Ens
# 5           27  79.260002  0.816014   MixGrowth Ens
# 6           28  79.446663  0.808346   MixGrowth Ens
# 7           33  78.913330  0.770004   MixGrowth Ens
# 8           38  79.266670  0.731662   MixGrowth Ens
# 9           42  79.224998  0.700988   MixGrowth Ens
# 10          43  78.986664  0.693320   MixGrowth Ens
# 11          48  78.989998  0.654978   MixGrowth Ens
# 12          49  79.136665  0.647310   MixGrowth Ens
# 13          53  79.260002  0.616636   MixGrowth Ens
# 14          57  79.033333  0.585963   MixGrowth Ens
# 15          58  79.330002  0.578294   MixGrowth Ens
# 16          63  79.213333  0.539952   MixGrowth Ens
# 17          68  79.300003  0.501611   MixGrowth Ens
# 18          73  79.330002  0.463269   MixGrowth Ens
# 19          74  78.993332  0.455600   MixGrowth Ens
# 20          78  78.870003  0.424927   MixGrowth Ens
# 21          80  78.084999  0.409590   MixGrowth Ens
# 22          83  78.073334  0.386585   MixGrowth Ens
# 23          88  77.959999  0.348243   MixGrowth Ens
# 24          93  77.559998  0.309901   MixGrowth Ens
# 25          94  77.884285  0.302233   MixGrowth Ens
# 26          95  77.415001  0.294564   MixGrowth Ens
# 27          96  76.915001  0.286896   MixGrowth Ens
# 28          98  74.620003  0.271559   MixGrowth Ens

# %%
# %matplotlib inline

g = sns.relplot(data=df, x='grow_epoch', y='acc',  
            sizes=(40, 400), alpha=.8, hue=df["color"], legend="auto", palette=["red", "black"], size='FLOPS')

plt.title("MixGrowth Ens at different growth epochs on CIFAR100")
plt.xlabel("growth epoch")
plt.ylabel("accuracy (%)")

plt.savefig("different_growth_points_v2.png", dpi=300,bbox_inches = "tight")
